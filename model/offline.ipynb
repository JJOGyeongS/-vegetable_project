# %%
import tensorflow.compat.v1 as tf
import numpy as np
from pandas.io.parsers import read_csv
tf.disable_v2_behavior()
model = tf.global_variables_initializer();

data = read_csv('cabbage/price data(cabbage).csv',sep=',')

xy = np.array(data, dtype=np.float32)
# Out:
# WARNING:tensorflow:From C:\Users\jsjs8\anaconda3\envs\tf2\lib\site-packages\tensorflow\python\compat\v2_compat.py:101: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
x_data = xy[:, 1:-1]
y_data = xy[:, [-1]]

# %%
X = tf.placeholder(tf.float32, shape=[None, 4])
Y = tf.placeholder(tf.float32, shape=[None, 1])
W = tf.Variable(tf.random_normal([4, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
hypothesis = tf.matmul(X, W) + b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.000005)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()

# %%
sess.run(tf.global_variables_initializer())

# %%
for step in range(100001):
    cost_, hypo_, _ = sess.run([cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 1000 == 0:
        print("#", step, " 손실 비용: ", cost_)
        print("- 배추 가격: ", hypo_[0])
# Out:
# # 0  손실 비용:  12824552.0
# - 배추 가격:  [10.39243]
# # 1000  손실 비용:  3786990.0
# - 배추 가격:  [33.808094]
# # 2000  손실 비용:  3219542.5
# - 배추 가격:  [566.9864]
# # 3000  손실 비용:  2867281.8
# - 배추 가격:  [987.8531]
# # 4000  손실 비용:  2647277.0
# - 배추 가격:  [1320.3446]
# # 5000  손실 비용:  2509475.2
# - 배추 가격:  [1583.1945]
# # 6000  손실 비용:  2423001.8
# - 배추 가격:  [1791.0789]
# # 7000  손실 비용:  2368637.0
# - 배추 가격:  [1955.5391]
# # 8000  손실 비용:  2334374.2
# - 배추 가격:  [2085.6682]
# # 9000  손실 비용:  2312700.2
# - 배추 가격:  [2188.648]
# # 10000  손실 비용:  2298910.0
# - 배추 가격:  [2270.151]
# # 11000  손실 비용:  2290058.5
# - 배추 가격:  [2334.6604]
# # 12000  손실 비용:  2284301.2
# - 배추 가격:  [2385.7231]
# # 13000  손실 비용:  2280481.8
# - 배추 가격:  [2426.1455]
# # 14000  손실 비용:  2277876.5
# - 배추 가격:  [2458.1462]
# # 15000  손실 비용:  2276031.8
# - 배추 가격:  [2483.4834]
# # 16000  손실 비용:  2274664.0
# - 배추 가격:  [2503.5466]
# # 17000  손실 비용:  2273594.8
# - 배추 가격:  [2519.4363]
# # 18000  손실 비용:  2272713.8
# - 배추 가격:  [2532.0208]
# # 19000  손실 비용:  2271950.5
# - 배추 가격:  [2541.9912]
# # 20000  손실 비용:  2271261.0
# - 배추 가격:  [2549.892]
# # 21000  손실 비용:  2270618.8
# - 배추 가격:  [2556.1558]
# # 22000  손실 비용:  2270005.5
# - 배추 가격:  [2561.122]
# # 23000  손실 비용:  2269411.5
# - 배추 가격:  [2565.064]
# # 24000  손실 비용:  2268830.0
# - 배추 가격:  [2568.1875]
# # 25000  손실 비용:  2268255.2
# - 배추 가격:  [2570.6726]
# # 26000  손실 비용:  2267686.0
# - 배추 가격:  [2572.6501]
# # 27000  손실 비용:  2267121.2
# - 배추 가격:  [2574.2234]
# # 28000  손실 비용:  2266558.2
# - 배추 가격:  [2575.4785]
# # 29000  손실 비용:  2265997.0
# - 배추 가격:  [2576.4978]
# # 30000  손실 비용:  2265437.0
# - 배추 가격:  [2577.302]
# # 31000  손실 비용:  2264879.8
# - 배추 가격:  [2577.9631]
# # 32000  손실 비용:  2264322.2
# - 배추 가격:  [2578.4543]
# # 33000  손실 비용:  2263765.5
# - 배추 가격:  [2578.925]
# # 34000  손실 비용:  2263209.8
# - 배추 가격:  [2579.248]
# # 35000  손실 비용:  2262656.0
# - 배추 가격:  [2579.5042]
# # 36000  손실 비용:  2262103.0
# - 배추 가격:  [2579.7598]
# # 37000  손실 비용:  2261550.0
# - 배추 가격:  [2580.015]
# # 38000  손실 비용:  2260997.5
# - 배추 가격:  [2580.2568]
# # 39000  손실 비용:  2260445.2
# - 배추 가격:  [2580.3638]
# # 40000  손실 비용:  2259895.8
# - 배추 가격:  [2580.4373]
# # 41000  손실 비용:  2259347.0
# - 배추 가격:  [2580.5056]
# # 42000  손실 비용:  2258798.5
# - 배추 가격:  [2580.5723]
# # 43000  손실 비용:  2258250.8
# - 배추 가격:  [2580.6372]
# # 44000  손실 비용:  2257703.2
# - 배추 가격:  [2580.7053]
# # 45000  손실 비용:  2257156.5
# - 배추 가격:  [2580.7727]
# # 46000  손실 비용:  2256610.0
# - 배추 가격:  [2580.8418]
# # 47000  손실 비용:  2256065.2
# - 배추 가격:  [2580.9146]
# # 48000  손실 비용:  2255522.2
# - 배추 가격:  [2580.9858]
# # 49000  손실 비용:  2254980.0
# - 배추 가격:  [2581.0635]
# # 50000  손실 비용:  2254438.2
# - 배추 가격:  [2581.1477]
# # 51000  손실 비용:  2253897.2
# - 배추 가격:  [2581.237]
# # 52000  손실 비용:  2253356.2
# - 배추 가격:  [2581.3293]
# # 53000  손실 비용:  2252816.0
# - 배추 가격:  [2581.4258]
# # 54000  손실 비용:  2252276.2
# - 배추 가격:  [2581.5261]
# # 55000  손실 비용:  2251738.8
# - 배추 가격:  [2581.617]
# # 56000  손실 비용:  2251202.2
# - 배추 가격:  [2581.7131]
# # 57000  손실 비용:  2250666.2
# - 배추 가격:  [2581.8096]
# # 58000  손실 비용:  2250130.5
# - 배추 가격:  [2581.906]
# # 59000  손실 비용:  2249597.0
# - 배추 가격:  [2581.9956]
# # 60000  손실 비용:  2249065.0
# - 배추 가격:  [2582.0967]
# # 61000  손실 비용:  2248532.8
# - 배추 가격:  [2582.1633]
# # 62000  손실 비용:  2248001.0
# - 배추 가격:  [2582.2305]
# # 63000  손실 비용:  2247470.0
# - 배추 가격:  [2582.2976]
# # 64000  손실 비용:  2246939.2
# - 배추 가격:  [2582.3652]
# # 65000  손실 비용:  2246408.8
# - 배추 가격:  [2582.4614]
# # 66000  손실 비용:  2245879.2
# - 배추 가격:  [2582.5688]
# # 67000  손실 비용:  2245349.5
# - 배추 가격:  [2582.6719]
# # 68000  손실 비용:  2244820.8
# - 배추 가격:  [2582.768]
# # 69000  손실 비용:  2244292.2
# - 배추 가격:  [2582.8586]
# # 70000  손실 비용:  2243764.0
# - 배추 가격:  [2582.928]
# # 71000  손실 비용:  2243236.5
# - 배추 가격:  [2582.9946]
# # 72000  손실 비용:  2242709.8
# - 배추 가격:  [2583.0632]
# # 73000  손실 비용:  2242184.8
# - 배추 가격:  [2583.1245]
# # 74000  손실 비용:  2241663.5
# - 배추 가격:  [2583.1685]
# # 75000  손실 비용:  2241142.5
# - 배추 가격:  [2583.213]
# # 76000  손실 비용:  2240622.0
# - 배추 가격:  [2583.2527]
# # 77000  손실 비용:  2240102.2
# - 배추 가격:  [2583.2864]
# # 78000  손실 비용:  2239582.0
# - 배추 가격:  [2583.3196]
# # 79000  손실 비용:  2239062.8
# - 배추 가격:  [2583.3533]
# # 80000  손실 비용:  2238544.0
# - 배추 가격:  [2583.378]
# # 81000  손실 비용:  2238025.5
# - 배추 가격:  [2583.401]
# # 82000  손실 비용:  2237507.5
# - 배추 가격:  [2583.4236]
# # 83000  손실 비용:  2236989.8
# - 배추 가격:  [2583.4463]
# # 84000  손실 비용:  2236472.8
# - 배추 가격:  [2583.4688]
# # 85000  손실 비용:  2235955.8
# - 배추 가격:  [2583.4822]
# # 86000  손실 비용:  2235440.0
# - 배추 가격:  [2583.4941]
# # 87000  손실 비용:  2234923.5
# - 배추 가격:  [2583.5063]
# # 88000  손실 비용:  2234408.2
# - 배추 가격:  [2583.5706]
# # 89000  손실 비용:  2233893.8
# - 배추 가격:  [2583.64]
# # 90000  손실 비용:  2233380.0
# - 배추 가격:  [2583.7083]
# # 91000  손실 비용:  2232871.0
# - 배추 가격:  [2583.775]
# # 92000  손실 비용:  2232362.5
# - 배추 가격:  [2583.8435]
# # 93000  손실 비용:  2231854.5
# - 배추 가격:  [2583.9111]
# # 94000  손실 비용:  2231346.5
# - 배추 가격:  [2583.979]
# # 95000  손실 비용:  2230839.0
# - 배추 가격:  [2584.0476]
# # 96000  손실 비용:  2230332.5
# - 배추 가격:  [2584.1162]
# # 97000  손실 비용:  2229826.5
# - 배추 가격:  [2584.1863]
# # 98000  손실 비용:  2229320.2
# - 배추 가격:  [2584.2551]
# # 99000  손실 비용:  2228815.0
# - 배추 가격:  [2584.3237]
# # 100000  손실 비용:  2228310.5
# - 배추 가격:  [2584.394]

# %%
saver = tf.train.Saver()
save_path = saver.save(sess, "cabbage/saved.cpkt")
print('학습된 모델을 저장했습니다.')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11844\2533188170.py in <module>
#       1 saver = tf.train.Saver()
# ----> 2 save_path = saver.save(sess, "cabbage/saved.cpkt")
#       3 print('학습된 모델을 저장했습니다.')
#
# ~\anaconda3\envs\tf2\lib\site-packages\tensorflow\python\training\saver.py in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state, strip_default_attrs, save_debug_info)
#    1188           model_checkpoint_path = sess.run(
#    1189               self.saver_def.save_tensor_name,
# -> 1190               {self.saver_def.filename_tensor_name: checkpoint_file})
#    1191
#    1192         model_checkpoint_path = compat.as_str(model_checkpoint_path)
#
# ~\anaconda3\envs\tf2\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     966     try:
#     967       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 968                          run_metadata_ptr)
#     969       if run_metadata:
#     970         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\anaconda3\envs\tf2\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1189     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1190       results = self._do_run(handle, final_targets, final_fetches,
# -> 1191                              feed_dict_tensor, options, run_metadata)
#    1192     else:
#    1193       results = []
#
# ~\anaconda3\envs\tf2\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1367     if handle is None:
#    1368       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1369                            run_metadata)
#    1370     else:
#    1371       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\anaconda3\envs\tf2\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1373   def _do_call(self, fn, *args):
#    1374     try:
# -> 1375       return fn(*args)
#    1376     except errors.OpError as e:
#    1377       message = compat.as_text(e.message)
#
# ~\anaconda3\envs\tf2\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1358       self._extend_graph()
#    1359       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1360                                       target_list, run_metadata)
#    1361
#    1362     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~\anaconda3\envs\tf2\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1451     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1452                                             fetch_list, target_list,
# -> 1453                                             run_metadata)
#    1454
#    1455   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xbe in position 104: invalid start byte
