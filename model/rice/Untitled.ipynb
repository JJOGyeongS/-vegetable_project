# %%
import tensorflow.compat.v1 as tf
import numpy as np
from pandas.io.parsers import read_csv
tf.disable_v2_behavior()
model = tf.global_variables_initializer();

data = read_csv('price data(rice).csv',sep=',')

xy = np.array(data, dtype=np.float32)

# %%
x_data = xy[:, 1:-1]
y_data = xy[:, [-1]]

# %%
X = tf.placeholder(tf.float32, shape=[None, 4])
Y = tf.placeholder(tf.float32, shape=[None, 1])
W = tf.Variable(tf.random_normal([4, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
hypothesis = tf.matmul(X, W) + b
cost = tf.reduce_mean(tf.square(hypothesis - Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.000005)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(100001):
    cost_, hypo_, _ = sess.run([cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 1000 == 0:
        print("#", step, " 손실 비용: ", cost_)
        print("- 쌀 가격: ", hypo_[0])
# Out:
# # 0  손실 비용:  2801303000.0
# - 쌀 가격:  [-3.231197]
# # 1000  손실 비용:  639031800.0
# - 쌀 가격:  [2061.231]
# # 2000  손실 비용:  460967040.0
# - 쌀 가격:  [11515.859]
# # 3000  손실 비용:  350159260.0
# - 쌀 가격:  [18981.68]
# # 4000  손실 비용:  280884740.0
# - 쌀 가격:  [24881.326]
# # 5000  손실 비용:  237474620.0
# - 쌀 가격:  [29546.123]
# # 6000  손실 비용:  210227280.0
# - 쌀 가격:  [33235.926]
# # 7000  손실 비용:  193094110.0
# - 쌀 가격:  [36155.27]
# # 8000  손실 비용:  182293810.0
# - 쌀 가격:  [38465.4]
# # 9000  손실 비용:  175459620.0
# - 쌀 가격:  [40293.684]
# # 10000  손실 비용:  171109470.0
# - 쌀 가격:  [41740.77]
# # 11000  손실 비용:  168315250.0
# - 쌀 가격:  [42886.258]
# # 12000  손실 비용:  166495710.0
# - 쌀 가격:  [43793.09]
# # 13000  손실 비용:  165286750.0
# - 쌀 가격:  [44511.02]
# # 14000  손실 비용:  164460340.0
# - 쌀 가격:  [45079.48]
# # 15000  손실 비용:  163873580.0
# - 쌀 가격:  [45529.65]
# # 16000  손실 비용:  163437060.0
# - 쌀 가격:  [45886.188]
# # 17000  손실 비용:  163094750.0
# - 쌀 가격:  [46168.656]
# # 18000  손실 비용:  162811500.0
# - 쌀 가격:  [46392.46]
# # 19000  손실 비용:  162565390.0
# - 쌀 가격:  [46569.85]
# # 20000  손실 비용:  162342610.0
# - 쌀 가격:  [46710.47]
# # 21000  손실 비용:  162134460.0
# - 쌀 가격:  [46822.035]
# # 22000  손실 비용:  161935680.0
# - 쌀 가격:  [46910.473]
# # 23000  손실 비용:  161742880.0
# - 쌀 가격:  [46980.836]
# # 24000  손실 비용:  161553800.0
# - 쌀 가격:  [47036.867]
# # 25000  손실 비용:  161367200.0
# - 쌀 가격:  [47081.453]
# # 26000  손실 비용:  161182240.0
# - 쌀 가격:  [47117.207]
# # 27000  손실 비용:  160998400.0
# - 쌀 가격:  [47145.48]
# # 28000  손실 비용:  160815310.0
# - 쌀 가격:  [47168.21]
# # 29000  손실 비용:  160632900.0
# - 쌀 가격:  [47186.85]
# # 30000  손실 비용:  160450960.0
# - 쌀 가격:  [47201.84]
# # 31000  손실 비용:  160269280.0
# - 쌀 가격:  [47213.03]
# # 32000  손실 비용:  160088140.0
# - 쌀 가격:  [47223.79]
# # 33000  손실 비용:  159907070.0
# - 쌀 가격:  [47232.58]
# # 34000  손실 비용:  159726290.0
# - 쌀 가격:  [47239.8]
# # 35000  손실 비용:  159546130.0
# - 쌀 가격:  [47243.85]
# # 36000  손실 비용:  159366160.0
# - 쌀 가격:  [47247.656]
# # 37000  손실 비용:  159186400.0
# - 쌀 가격:  [47251.24]
# # 38000  손실 비용:  159006770.0
# - 쌀 가격:  [47254.77]
# # 39000  손실 비용:  158827230.0
# - 쌀 가격:  [47258.3]
# # 40000  손실 비용:  158648380.0
# - 쌀 가격:  [47261.727]
# # 41000  손실 비용:  158469860.0
# - 쌀 가격:  [47265.098]
# # 42000  손실 비용:  158291420.0
# - 쌀 가격:  [47268.44]
# # 43000  손실 비용:  158113070.0
# - 쌀 가격:  [47271.59]
# # 44000  손실 비용:  157934750.0
# - 쌀 가격:  [47274.56]
# # 45000  손실 비용:  157756930.0
# - 쌀 가격:  [47277.35]
# # 46000  손실 비용:  157579520.0
# - 쌀 가격:  [47279.504]
# # 47000  손실 비용:  157402160.0
# - 쌀 가격:  [47281.12]
# # 48000  손실 비용:  157225020.0
# - 쌀 가격:  [47282.73]
# # 49000  손실 비용:  157048460.0
# - 쌀 가격:  [47284.336]
# # 50000  손실 비용:  156872320.0
# - 쌀 가격:  [47285.957]
# # 51000  손실 비용:  156696300.0
# - 쌀 가격:  [47287.566]
# # 52000  손실 비용:  156520460.0
# - 쌀 가격:  [47289.195]
# # 53000  손실 비용:  156344770.0
# - 쌀 가격:  [47290.816]
# # 54000  손실 비용:  156169220.0
# - 쌀 가격:  [47292.445]
# # 55000  손실 비용:  155993840.0
# - 쌀 가격:  [47294.082]
# # 56000  손실 비용:  155818580.0
# - 쌀 가격:  [47295.72]
# # 57000  손실 비용:  155643470.0
# - 쌀 가격:  [47297.355]
# # 58000  손실 비용:  155468530.0
# - 쌀 가격:  [47298.992]
# # 59000  손실 비용:  155293780.0
# - 쌀 가격:  [47300.65]
# # 60000  손실 비용:  155119100.0
# - 쌀 가격:  [47302.293]
# # 61000  손실 비용:  154944640.0
# - 쌀 가격:  [47303.95]
# # 62000  손실 비용:  154770640.0
# - 쌀 가격:  [47305.594]
# # 63000  손실 비용:  154597840.0
# - 쌀 가격:  [47307.184]
# # 64000  손실 비용:  154425180.0
# - 쌀 가격:  [47308.75]
# # 65000  손실 비용:  154252670.0
# - 쌀 가격:  [47310.188]
# # 66000  손실 비용:  154080340.0
# - 쌀 가격:  [47311.586]
# # 67000  손실 비용:  153908030.0
# - 쌀 가격:  [47312.926]
# # 68000  손실 비용:  153735920.0
# - 쌀 가격:  [47314.156]
# # 69000  손실 비용:  153563950.0
# - 쌀 가격:  [47315.39]
# # 70000  손실 비용:  153392100.0
# - 쌀 가격:  [47316.55]
# # 71000  손실 비용:  153220370.0
# - 쌀 가격:  [47317.613]
# # 72000  손실 비용:  153048780.0
# - 쌀 가격:  [47318.67]
# # 73000  손실 비용:  152877310.0
# - 쌀 가격:  [47319.734]
# # 74000  손실 비용:  152706000.0
# - 쌀 가격:  [47320.71]
# # 75000  손실 비용:  152534750.0
# - 쌀 가격:  [47321.598]
# # 76000  손실 비용:  152363680.0
# - 쌀 가격:  [47322.49]
# # 77000  손실 비용:  152193260.0
# - 쌀 가격:  [47323.293]
# # 78000  손실 비용:  152023780.0
# - 쌀 가격:  [47323.95]
# # 79000  손실 비용:  151854380.0
# - 쌀 가격:  [47324.6]
# # 80000  손실 비용:  151685250.0
# - 쌀 가격:  [47326.04]
# # 81000  손실 비용:  151516260.0
# - 쌀 가격:  [47327.684]
# # 82000  손실 비용:  151347400.0
# - 쌀 가격:  [47329.332]
# # 83000  손실 비용:  151178670.0
# - 쌀 가격:  [47330.984]
# # 84000  손실 비용:  151010130.0
# - 쌀 가격:  [47332.64]
# # 85000  손실 비용:  150841700.0
# - 쌀 가격:  [47334.297]
# # 86000  손실 비용:  150673390.0
# - 쌀 가격:  [47335.96]
# # 87000  손실 비용:  150505260.0
# - 쌀 가격:  [47337.633]
# # 88000  손실 비용:  150337310.0
# - 쌀 가격:  [47339.305]
# # 89000  손실 비용:  150169420.0
# - 쌀 가격:  [47340.98]
# # 90000  손실 비용:  150001700.0
# - 쌀 가격:  [47342.656]
# # 91000  손실 비용:  149834140.0
# - 쌀 가격:  [47344.336]
# # 92000  손실 비용:  149667870.0
# - 쌀 가격:  [47346.]
# # 93000  손실 비용:  149501980.0
# - 쌀 가격:  [47347.664]
# # 94000  손실 비용:  149336140.0
# - 쌀 가격:  [47349.324]
# # 95000  손실 비용:  149170540.0
# - 쌀 가격:  [47350.984]
# # 96000  손실 비용:  149005070.0
# - 쌀 가격:  [47352.668]
# # 97000  손실 비용:  148839730.0
# - 쌀 가격:  [47354.34]
# # 98000  손실 비용:  148674460.0
# - 쌀 가격:  [47356.016]
# # 99000  손실 비용:  148509390.0
# - 쌀 가격:  [47357.51]
# # 100000  손실 비용:  148344460.0
# - 쌀 가격:  [47358.867]

# %%
saver = tf.train.Saver()
save_path = saver.save(sess, "./savedrice.cpkt")
print('학습된 모델을 저장했습니다.')
# Out:
# 학습된 모델을 저장했습니다.
