# %%
import tensorflow.compat.v1 as tf
import numpy as np
from pandas.io.parsers import read_csv
tf.disable_v2_behavior()
model = tf.global_variables_initializer();

data = read_csv('price data.csv',sep=',')

xy = np.array(data, dtype=np.float32)

# %%
x_data = xy[:, 1:-1]
y_data = xy[:, [-1]]

# %%
X = tf.placeholder(tf.float32, shape=[None, 4])
Y = tf.placeholder(tf.float32, shape=[None, 1])
W = tf.Variable(tf.random_normal([4, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
hypothesis = tf.matmul(X, W) + b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.000005)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()

# %%
sess.run(tf.global_variables_initializer())

# %%
for step in range(100001):
    cost_, hypo_, _ = sess.run([cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 1000 == 0:
        print("#", step, " 손실 비용: ", cost_)
        print("- 배추 가격: ", hypo_[0])
# Out:
# # 0  손실 비용:  12356218.0
# - 배추 가격:  [-14.146551]
# # 1000  손실 비용:  3791479.2
# - 배추 가격:  [29.520725]
# # 2000  손실 비용:  3222683.5
# - 배추 가격:  [563.5115]
# # 3000  손실 비용:  2869312.5
# - 배추 가격:  [985.06573]
# # 4000  손실 비용:  2648545.2
# - 배추 가격:  [1318.1261]
# # 5000  손실 비용:  2510249.0
# - 배추 가격:  [1581.4387]
# # 6000  손실 비용:  2423461.2
# - 배추 가격:  [1789.6958]
# # 7000  손실 비용:  2368899.0
# - 배추 가격:  [1954.4525]
# # 8000  손실 비용:  2334512.5
# - 배추 가격:  [2084.8196]
# # 9000  손실 비용:  2312760.5
# - 배추 가격:  [2187.9878]
# # 10000  손실 비용:  2298922.0
# - 배추 가격:  [2269.6392]
# # 11000  손실 비용:  2290040.2
# - 배추 가격:  [2334.267]
# # 12000  손실 비용:  2284263.8
# - 배추 가격:  [2385.423]
# # 13000  손실 비용:  2280432.0
# - 배추 가격:  [2425.9194]
# # 14000  손실 비용:  2277819.8
# - 배추 가격:  [2457.979]
# # 15000  손실 비용:  2275970.0
# - 배추 가격:  [2483.3625]
# # 16000  손실 비용:  2274599.5
# - 배추 가격:  [2503.4626]
# # 17000  손실 비용:  2273529.2
# - 배추 가격:  [2519.381]
# # 18000  손실 비용:  2272646.8
# - 배추 가격:  [2531.9897]
# # 19000  손실 비용:  2271882.5
# - 배추 가격:  [2541.9788]
# # 20000  손실 비용:  2271193.0
# - 배추 가격:  [2549.893]
# # 21000  손실 비용:  2270549.8
# - 배추 가격:  [2556.169]
# # 22000  손실 비용:  2269937.0
# - 배추 가격:  [2561.1443]
# # 23000  손실 비용:  2269342.8
# - 배추 가격:  [2565.092]
# # 24000  손실 비용:  2268760.8
# - 배추 가격:  [2568.2222]
# # 25000  손실 비용:  2268186.2
# - 배추 가격:  [2570.7112]
# # 26000  손실 비용:  2267617.2
# - 배추 가격:  [2572.6921]
# # 27000  손실 비용:  2267052.2
# - 배추 가격:  [2582.488]
# # 66000  손실 비용:  2245813.2
# - 배추 가격:  [2582.5889]
# # 67000  손실 비용:  2245283.5
# - 배추 가격:  [2582.6938]
# # 68000  손실 비용:  2244754.5
# - 배추 가격:  [2582.7944]
# # 69000  손실 비용:  2244225.8
# - 배추 가격:  [2582.8853]
# # 70000  손실 비용:  2243697.8
# - 배추 가격:  [2582.9692]
# # 71000  손실 비용:  2243170.5
# - 배추 가격:  [2583.0493]
# # 72000  손실 비용:  2242643.8
# - 배추 가격:  [2583.1184]
# # 73000  손실 비용:  2242119.5
# - 배추 가격:  [2583.1787]
# # 74000  손실 비용:  2241598.0
# - 배추 가격:  [2583.2231]
# # 75000  손실 비용:  2241077.0
# - 배추 가격:  [2583.2673]
# # 76000  손실 비용:  2240556.5
# - 배추 가격:  [2583.309]
# # 77000  손실 비용:  2240036.5
# - 배추 가격:  [2583.3428]
# # 78000  손실 비용:  2239517.0
# - 배추 가격:  [2583.376]
# # 79000  손실 비용:  2238997.5
# - 배추 가격:  [2583.41]
# # 80000  손실 비용:  2238478.8
# - 배추 가격:  [2583.4365]
# # 81000  손실 비용:  2237960.5
# - 배추 가격:  [2583.4592]
# # 82000  손실 비용:  2237442.5
# - 배추 가격:  [2583.482]
# # 83000  손실 비용:  2236924.8
# - 배추 가격:  [2583.505]
# # 84000  손실 비용:  2236407.5
# - 배추 가격:  [2583.5278]
# # 85000  손실 비용:  2235890.8
# - 배추 가격:  [2583.5422]
# # 86000  손실 비용:  2235374.5
# - 배추 가격:  [2583.5547]
# # 87000  손실 비용:  2234858.5
# - 배추 가격:  [2583.567]
# # 88000  손실 비용:  2234343.0
# - 배추 가격:  [2583.6245]
# # 89000  손실 비용:  2233828.5
# - 배추 가격:  [2583.6936]
# # 90000  손실 비용:  2233315.0
# - 배추 가격:  [2583.7622]
# # 91000  손실 비용:  2232806.0
# - 배추 가격:  [2583.83]
# # 92000  손실 비용:  2232297.5
# - 배추 가격:  [2583.8975]
# # 93000  손실 비용:  2231789.8
# - 배추 가격:  [2583.9658]
# # 94000  손실 비용:  2231281.8
# - 배추 가격:  [2584.0337]
# # 95000  손실 비용:  2230774.5
# - 배추 가격:  [2584.1016]
# # 96000  손실 비용:  2230267.8
# - 배추 가격:  [2584.17]
# # 97000  손실 비용:  2229762.0
# - 배추 가격:  [2584.2397]
# # 98000  손실 비용:  2229256.0
# - 배추 가격:  [2584.3086]
# # 99000  손실 비용:  2228750.2
# - 배추 가격:  [2584.378]
# # 100000  손실 비용:  2228245.8
# - 배추 가격:  [2584.4478]

# %%
saver = tf.train.Saver()
save_path = saver.save(sess, "./saved.cpkt")
print('학습된 모델을 저장했습니다.')
# Out:
# 학습된 모델을 저장했습니다.
